# %%
list1 = Range[-0.20, -0.16, 0.05];
list2 = Range[0, 0.9, 0.2];
list = Join[list1, list2];
w = -2;
graph1 = 
  ContourPlot[
   v^2/2 + w*u^2/2 + u^4/4 == list,  {u, -4, 4}, {v, -4, 4}, 
   PlotRange -> All, AspectRatio -> 3/4, ImageSize -> 400, 
   PlotPoints -> 50, 
   PlotLabel -> 
    "Рис.1: Фазовый портрет консервативной системы. k=1"];
graph2 = Graphics[{
    PointSize[Large], Red,
    Point[{
      {0, 0},
      {Re[I Sqrt[w/1]], 0},
      {Re[-I Sqrt[w/1]], 0}
      }]
    }];
 
 Show[{graph1}, graph2]
# Out:
# -Graphics-
