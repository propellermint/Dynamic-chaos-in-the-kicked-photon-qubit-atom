# %%
using ITensors

function main(; Nx = 40,
                Ny = 3,
                U = -7.0,
                t = 1.0)
  N = Nx * Ny

  sweeps = Sweeps(40)
  maxdim!(sweeps, 1600)
  cutoff!(sweeps, 1e-13)
  @show sweeps

  sites = siteinds("Electron", N;
                   conserve_qns = true)

  lattice = square_lattice(Nx, Ny;
                           yperiodic = true, xperiodic = false)

  ampo = AutoMPO()
  for b in lattice
    ampo += -t, "Cdagup", b.s1, "Cup", b.s2
    ampo += -t, "Cdagup", b.s2, "Cup", b.s1
    ampo += -t, "Cdagdn", b.s1, "Cdn", b.s2
    ampo += -t, "Cdagdn", b.s2, "Cdn", b.s1
  end
  for n in 1:N
    ampo += U, "Nupdn", n
  end
  H = MPO(ampo,sites)
  
  for x in 1:10
    lol = 120 - 38 - x
    state = append!(["Up" for _ in 1:38],["Dn" for _ in 1:x],["0" for _ in 1:lol])
    psi0 = randomMPS(sites, state)

    energy,psi = dmrg(H, psi0, sweeps)
    @show t, U
    @show flux(psi)
    @show maxlinkdim(psi)
    @show energy
    return
  end

end
# Out:
# main (generic function with 1 method)

# %%
main()
# Out:
# sweeps = Sweeps
# 1 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 2 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 3 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 4 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 5 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 6 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 7 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 8 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 9 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 10 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 11 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 12 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 13 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 14 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 15 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 16 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 17 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 18 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 19 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 20 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 21 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 22 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 23 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 24 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 25 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 26 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 27 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 28 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 29 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 30 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 31 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 32 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 33 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 34 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 35 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 36 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 37 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 38 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 39 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
# 40 cutoff=1.0E-13, maxdim=1600, mindim=1, noise=0.0E+00
#
# After sweep 1 energy=-11.244358552984 maxlinkdim=4 maxerr=9.56E-16 time=1.203
# After sweep 2 energy=-16.810827546040 maxlinkdim=12 maxerr=5.67E-14 time=0.849
# After sweep 3 energy=-26.324248845586 maxlinkdim=58 maxerr=9.61E-14 time=0.864
# After sweep 4 energy=-33.051132875272 maxlinkdim=215 maxerr=9.99E-14 time=2.319
# After sweep 5 energy=-39.487127063585 maxlinkdim=533 maxerr=9.99E-14 time=9.583
# After sweep 6 energy=-45.530525615432 maxlinkdim=1102 maxerr=9.99E-14 time=32.701
# After sweep 7 energy=-51.500241266281 maxlinkdim=1600 maxerr=2.97E-11 time=100.133
# After sweep 8 energy=-56.877791591973 maxlinkdim=1600 maxerr=1.31E-09 time=215.497
# After sweep 9 energy=-62.222079328028 maxlinkdim=1600 maxerr=1.08E-09 time=294.034
# After sweep 10 energy=-66.779064814975 maxlinkdim=1600 maxerr=1.05E-09 time=277.335
# After sweep 11 energy=-71.394676909031 maxlinkdim=1600 maxerr=1.17E-09 time=241.804
# After sweep 12 energy=-75.075999615671 maxlinkdim=1600 maxerr=6.55E-10 time=237.399
# After sweep 13 energy=-78.794323900177 maxlinkdim=1600 maxerr=5.75E-10 time=271.700
# After sweep 14 energy=-81.491662368358 maxlinkdim=1600 maxerr=2.37E-10 time=242.102
# After sweep 15 energy=-84.317781465954 maxlinkdim=1600 maxerr=3.81E-10 time=253.891
# After sweep 16 energy=-86.045998086896 maxlinkdim=1600 maxerr=3.51E-10 time=274.838
# After sweep 17 energy=-87.952571374190 maxlinkdim=1600 maxerr=7.12E-10 time=274.527
# After sweep 18 energy=-89.250918245339 maxlinkdim=1600 maxerr=7.56E-10 time=316.348
# After sweep 19 energy=-90.294621007307 maxlinkdim=1600 maxerr=1.05E-09 time=315.314
# After sweep 20 energy=-91.188664422981 maxlinkdim=1600 maxerr=1.20E-09 time=319.980
# After sweep 21 energy=-91.775043493108 maxlinkdim=1600 maxerr=2.90E-09 time=350.045
# After sweep 22 energy=-92.302436156981 maxlinkdim=1600 maxerr=7.76E-09 time=355.878
# After sweep 23 energy=-92.755291261536 maxlinkdim=1600 maxerr=1.04E-08 time=370.661
# After sweep 24 energy=-93.071001785047 maxlinkdim=1600 maxerr=8.97E-09 time=395.480
# After sweep 25 energy=-93.298411608144 maxlinkdim=1600 maxerr=1.27E-08 time=430.756
# After sweep 26 energy=-93.458502360073 maxlinkdim=1600 maxerr=1.60E-08 time=522.711
# After sweep 27 energy=-93.582522573407 maxlinkdim=1600 maxerr=1.20E-08 time=531.382
# After sweep 28 energy=-93.713977731504 maxlinkdim=1600 maxerr=1.13E-08 time=568.911
# After sweep 29 energy=-93.806179354617 maxlinkdim=1600 maxerr=1.21E-08 time=667.439
# After sweep 30 energy=-93.858852369372 maxlinkdim=1600 maxerr=1.22E-08 time=682.430
# After sweep 31 energy=-93.893112440680 maxlinkdim=1600 maxerr=1.29E-08 time=767.910
# After sweep 32 energy=-93.916639945596 maxlinkdim=1600 maxerr=1.48E-08 time=764.253
# After sweep 33 energy=-93.932415702359 maxlinkdim=1600 maxerr=1.81E-08 time=782.546
# InterruptException:
#
# Stacktrace:
#   [1] _mapreduce_block!(f::Any, op::Any, initop::Any, dims::NTuple{4, Int64}, strides::Tuple{NTuple{4, Int64}, NTuple{4, Int64}}, offsets::Tuple{Int64, Int64}, costs::NTuple{4, Int64}, arrays::Tuple{Strided.StridedView{Float64, 4, Vector{Float64}, typeof(identity)}, Strided.StridedView{Float64, 4, Vector{Float64}, typeof(identity)}})
#     @ Strided ~/.julia/packages/Strided/BFLNk/src/mapreduce.jl:135
#   [2] _mapreduce_order!(f::Any, op::Any, initop::Any, dims::NTuple{4, Int64}, strides::Tuple{NTuple{4, Int64}, NTuple{4, Int64}}, arrays::Tuple{Strided.StridedView{Float64, 4, Vector{Float64}, typeof(identity)}, Strided.StridedView{Float64, 4, Vector{Float64}, typeof(identity)}})
#     @ Strided ~/.julia/packages/Strided/BFLNk/src/mapreduce.jl:120
#   [3] _mapreduce_fuse!(f::Any, op::Any, initop::Any, dims::NTuple{4, Int64}, arrays::Tuple{Strided.StridedView{Float64, 4, Vector{Float64}, typeof(identity)}, Strided.StridedView{Float64, 4, Vector{Float64}, typeof(identity)}})
#     @ Strided ~/.julia/packages/Strided/BFLNk/src/mapreduce.jl:98
#   [4] map!
#     @ ~/.julia/packages/Strided/BFLNk/src/mapreduce.jl:32 [inlined]
#   [5] copyto!
#     @ ~/.julia/packages/Strided/BFLNk/src/abstractstridedview.jl:43 [inlined]
#   [6] copy(a::Strided.StridedView{Float64, 4, Vector{Float64}, typeof(identity)})
#     @ Strided ~/.julia/packages/Strided/BFLNk/src/stridedview.jl:56
#   [7] maybeunstrided
#     @ ~/.julia/packages/Strided/BFLNk/src/macros.jl:34 [inlined]
#   [8] _contract!(CT::NDTensors.DenseTensor{Float64, 4, NTuple{4, Int64}, NDTensors.Dense{Float64, SubArray{Float64, 1, Vector{Float64}, Tuple{UnitRange{Int64}}, true}}}, AT::NDTensors.DenseTensor{Float64, 4, NTuple{4, Int64}, NDTensors.Dense{Float64, SubArray{Float64, 1, Vector{Float64}, Tuple{UnitRange{Int64}}, true}}}, BT::NDTensors.DenseTensor{Float64, 4, NTuple{4, Int64}, NDTensors.Dense{Float64, SubArray{Float64, 1, Vector{Float64}, Tuple{UnitRange{Int64}}, true}}}, props::NDTensors.ContractionProperties{4, 4, 4}, α::Float64, β::Float64)
#     @ NDTensors ~/.julia/packages/NDTensors/b7X2X/src/dense.jl:858
#   [9] contract!
#     @ ~/.julia/packages/NDTensors/b7X2X/src/dense.jl:838 [inlined]
#  [10] contract!(R::NDTensors.BlockSparseTensor{Float64, 4, NTuple{4, Index{Vector{Pair{QN, Int64}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelsR::NTuple{4, Int64}, T1::NDTensors.BlockSparseTensor{Float64, 4, IndexSet{4, Index{Vector{Pair{QN, Int64}}}, NTuple{4, Index{Vector{Pair{QN, Int64}}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelsT1::NTuple{4, Int64}, T2::NDTensors.BlockSparseTensor{Float64, 4, IndexSet{4, Index{Vector{Pair{QN, Int64}}}, NTuple{4, Index{Vector{Pair{QN, Int64}}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelsT2::NTuple{4, Int64}, contraction_plan::Vector{Tuple{Block{4}, Block{4}, Block{4}}})
#     @ NDTensors ~/.julia/packages/NDTensors/b7X2X/src/blocksparse/blocksparsetensor.jl:956
#  [11] contract(T1::NDTensors.BlockSparseTensor{Float64, 4, IndexSet{4, Index{Vector{Pair{QN, Int64}}}, NTuple{4, Index{Vector{Pair{QN, Int64}}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelsT1::NTuple{4, Int64}, T2::NDTensors.BlockSparseTensor{Float64, 4, IndexSet{4, Index{Vector{Pair{QN, Int64}}}, NTuple{4, Index{Vector{Pair{QN, Int64}}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelsT2::NTuple{4, Int64}, labelsR::NTuple{4, Int64})
#     @ NDTensors ~/.julia/packages/NDTensors/b7X2X/src/blocksparse/blocksparsetensor.jl:867
#  [12] contract(T1::NDTensors.BlockSparseTensor{Float64, 4, IndexSet{4, Index{Vector{Pair{QN, Int64}}}, NTuple{4, Index{Vector{Pair{QN, Int64}}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelsT1::NTuple{4, Int64}, T2::NDTensors.BlockSparseTensor{Float64, 4, IndexSet{4, Index{Vector{Pair{QN, Int64}}}, NTuple{4, Index{Vector{Pair{QN, Int64}}}}}, NDTensors.BlockSparse{Float64, Vector{Float64}, 4}}, labelsT2::NTuple{4, Int64})
#     @ NDTensors ~/.julia/packages/NDTensors/b7X2X/src/blocksparse/blocksparsetensor.jl:866
#  [13] _contract(A::ITensor{4}, B::ITensor{4})
#     @ ITensors ~/.julia/packages/ITensors/Ligbx/src/itensor.jl:1304
#  [14] *(A::ITensor{4}, B::ITensor{4})
#     @ ITensors ~/.julia/packages/ITensors/Ligbx/src/itensor.jl:1363
#  [15] *
#     @ ./operators.jl:560 [inlined]
#  [16] makeL!(P::ProjMPO, psi::MPS, k::Int64)
#     @ ITensors ~/.julia/packages/ITensors/Ligbx/src/mps/projmpo.jl:165
#  [17] position!
#     @ ~/.julia/packages/ITensors/Ligbx/src/mps/projmpo.jl:202 [inlined]
#  [18] macro expansion
#     @ ~/.julia/packages/ITensors/Ligbx/src/mps/dmrg.jl:184 [inlined]
#  [19] macro expansion
#     @ ~/.julia/packages/TimerOutputs/PZq45/src/TimerOutput.jl:226 [inlined]
#  [20] macro expansion
#     @ ~/.julia/packages/ITensors/Ligbx/src/mps/dmrg.jl:183 [inlined]
#  [21] macro expansion
#     @ ./timing.jl:287 [inlined]
#  [22] dmrg(PH::ProjMPO, psi0::MPS, sweeps::Sweeps; kwargs::Base.Iterators.Pairs{Union{}, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#     @ ITensors ~/.julia/packages/ITensors/Ligbx/src/mps/dmrg.jl:173
#  [23] dmrg
#     @ ~/.julia/packages/ITensors/Ligbx/src/mps/dmrg.jl:108 [inlined]
#  [24] #dmrg#828
#     @ ~/.julia/packages/ITensors/Ligbx/src/mps/dmrg.jl:39 [inlined]
#  [25] dmrg
#     @ ~/.julia/packages/ITensors/Ligbx/src/mps/dmrg.jl:33 [inlined]
#  [26] main(; Nx::Int64, Ny::Int64, U::Float64, t::Float64)
#     @ Main ./In[7]:37
#  [27] main()
#     @ Main ./In[7]:7
#  [28] top-level scope
#     @ In[8]:1
#  [29] eval
#     @ ./boot.jl:360 [inlined]
#  [30] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#     @ Base ./loading.jl:1094
